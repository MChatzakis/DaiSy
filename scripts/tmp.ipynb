# %%
import BruteForceSearch

# %%
import numpy as np

# %%
database = np.array([
    [0.0, 0.0],
    [1.0, 1.0],
    [2.0, 2.0],
    [3.0, 3.0]
], dtype=np.float32)

# Créer une requête simple
query = np.array([
    [1.5, 1.5]
], dtype=np.float32)

# %%
# Créer une instance de BruteForceSearch
bf = BruteForceSearch.BruteForceSearch(BruteForceSearch.DistanceType.L2_SQUARED)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Créer une instance de BruteForceSearch
# ----> 2 bf = BruteForceSearch.BruteForceSearch(BruteForceSearch.DistanceType.L2_SQUARED)
#
# AttributeError: module 'BruteForceSearch' has no attribute 'DistanceType'

# %%
bfs.setNumThreads(4)
bfs.buildIndex(np.random.rand(100, 128).astype(np.float32), 100, 128)

queries = np.random.rand(5, 128).astype(np.float32)
indices, distances = bfs.searchIndex(queries, 5, 3)
print(indices)
print(distances)
